# %% [markdown]
# <a href="https://colab.research.google.com/github/AJ-Horch/grounded_data_analyst/blob/main/covidmoviesclean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pdfplumber

# %%
import numpy as np
import pandas as pd

import pdfplumber

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# There is a lot of data to choose from. But to get started I'll look at just the a few files. In these pdf files there are broad categories such as:
# - Gross box office revenue
# - top films of the year
# - countries of orgin
# - genre
# - directors
# - independent flims
# - distributors
#
# The objective of these practice is to write a white paper. The paper will focus on:
# - Admission patterns
# - distribution of genres
# - market share across distriutors

# %%
pdf_path='/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2019 - BFI yearbook 2019 - 888.pdf'
page_num = 11

page_tables = []

with pdfplumber.open(pdf_path) as pdf:
  page = pdf.pages[page_num-1]
  # page_tables is a list of list of list
  # extracted from special table objects
  page_tables = [t.extract() for t in page.find_tables()]

page_tables
# Out:
# [[['Month', '2017 (million)', '2018 (million)', '% +/- on 2017'],
#   ['January', '15.0', '16.2', '8.0'],
#   ['February', '16.5', '16.1', '-2.3'],
#   ['March', '16.2', '13.5', '-16.2'],
#   ['April', '15.6', '15.5', '-0.9'],
#   ['May', '11.3', '13.7', '21.0'],
#   ['June', '9.6', '10.4', '8.6'],
#   ['July', '17.8', '15.6', '-12.3'],
#   ['August', '14.5', '19.2', '32.8'],
#   ['September', '10.8', '10.1', '-6.0'],
#   ['October', '12.1', '16.0', '32.6'],
#   ['November', '14.1', '14.8', '5.4'],
#   ['December', '17.2', '15.7', '-8.7'],
#   ['Total', '170.6', '177.0', '3.7']]]

# %%
# convert the list o lists into a DF
table = page_tables[0]
pd.DataFrame(table[1:-1], columns=table[0])
# Out:
#         Month 2017 (million) 2018 (million) % +/- on 2017
# 0     January           15.0           16.2           8.0
# 1    February           16.5           16.1          -2.3
# 2       March           16.2           13.5         -16.2
# 3       April           15.6           15.5          -0.9
# 4         May           11.3           13.7          21.0
# 5        June            9.6           10.4           8.6
# 6        July           17.8           15.6         -12.3
# 7      August           14.5           19.2          32.8
# 8   September           10.8           10.1          -6.0
# 9     October           12.1           16.0          32.6
# 10   November           14.1           14.8           5.4
# 11   December           17.2           15.7          -8.7

# %%
# extract mutliple pages
def extract_tables(pdf_path, pages=[], print_tables=True):
  """
  Extract all tables found in the PDF.

  pdf_path : file path pointing to the PDF
  pages : the page number(S) to read
  print_tables :  whether to also print out
  all the tables that are found (default TRUE)

  returns: a list of pd DFs
  """

  print(f"Reading {pdf_path}")

  tables = []

  with pdfplumber.open(pdf_path) as pdf:
    for page_num in pages:
      page = pdf.pages[page_num-1]

      # page_table is a list of lists
      # extracted from special Table objects
      page_tables = [t.extract() for t in page.find_tables()]

      #in each case, table is now a list of lists
      # first is colmn headers
      dfs= [pd.DataFrame(table[1:-1], columns=table[0]) for table in page_tables]

      tables.extend(dfs)

  print(f"{len(tables)} tables found")

  if len(tables) > 0:
    if print_tables:
      for index, df in enumerate(tables):
        print(f"\n#######################\n\tTable {index}\n##################\n")
        display(df)
  return tables

# %% [markdown]
# The variable **tables** that stores the output of our function is now a list of DataFrames, each representing one table extracted from a PDF.

# %% [markdown]
# ## 2018

# %%
# test function
tables_2018 = extract_tables("/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2019 - BFI yearbook 2019 - 888.pdf", pages=[11,34,70])
# Out:
# Reading /content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2019 - BFI yearbook 2019 - 888.pdf
# 3 tables found
#
# #######################
# 	Table 0
# ##################
#         Month 2017 (million) 2018 (million) % +/- on 2017
# 0     January           15.0           16.2           8.0
# 1    February           16.5           16.1          -2.3
# 2       March           16.2           13.5         -16.2
# 3       April           15.6           15.5          -0.9
# 4         May           11.3           13.7          21.0
# 5        June            9.6           10.4           8.6
# 6        July           17.8           15.6         -12.3
# 7      August           14.5           19.2          32.8
# 8   September           10.8           10.1          -6.0
# 9     October           12.1           16.0          32.6
# 10   November           14.1           14.8           5.4
# ...

# %% [markdown]
# ### Admissions

# %%
# need to add the year to these tables
admissions_2018 = (
    tables_2018[0]
    .iloc[:,[0,2]]
)

admissions_2018.columns = ['Month', 'Admissions (million)']

admissions_2018.insert(0, 'Year', 2018)

admissions_2018.head()
# Out:
#    Year     Month Admissions (million)
# 0  2018   January                 16.2
# 1  2018  February                 16.1
# 2  2018     March                 13.5
# 3  2018     April                 15.5
# 4  2018       May                 13.7

# %% [markdown]
# ### Genres

# %%
# need to add a year column to the genre table
# remove unuseful columns
genres_2018 = (
    tables_2018[1]
    .drop(columns =[tables_2018[1].columns[2], tables_2018[1].columns[4]])
)

genres_2018.insert(0, "Year", 2018)

genres_2018.column = ["Year", "Genre", "Number of releases",
                      "Gross box office (£ million)",
                      "Top performing title"]

genres_2018.columns = genres_2018.columns.str.replace('\n', ' ')


genres_2018.head()
# Out:
# <ipython-input-333-71cc34500c6c>:10: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   genres_2018.column = ["Year", "Genre", "Number of releases",
#    Year      Genre Number of releases Gross box office (£ million)  \
# 0  2018     Action                 77                        361.3
# 1  2018  Animation                 46                        242.2
# 2  2018      Drama                246                        154.1
# 3  2018     Comedy                144                         88.3
# 4  2018     Biopic                  5                         78.5
#
#            Top performing title
# 0        Avengers: Infinity War
# 1                 Incredibles 2
# 2                A Star Is Born
# 3  Johnny English Strikes Again
# 4             Bohemian Rhapsody

# %% [markdown]
# ### Distributors

# %%
# add year to the distributor table
# remove the tenth row, its a total of the others
distributors_2018 = (
    tables_2018[2]
    .drop(index=10) # drop the tenth row
)

distributors_2018.insert(0, "Year", 2018)

distributors_2018.column = ["Year", "Distributors", "Market share",
                      "Gross box office (£ million)"]
distributors_2018.head(10)
# Out:
# <ipython-input-334-169a73c1b870>:10: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   distributors_2018.column = ["Year", "Distributors", "Market share",
#    Year       Distributor Market share\n(%) Films on release\nin 2018  \
# 0  2018       Walt Disney              23.6                        24
# 1  2018         Universal              19.5                        40
# 2  2018  20th Century Fox              14.5                        28
# 3  2018       Warner Bros              13.9                        31
# 4  2018              Sony              10.7                        33
# 5  2018         Paramount               4.8                        12
# 6  2018        eOne Films               3.2                        22
# 7  2018       StudioCanal               2.8                        31
# 8  2018         Lionsgate               1.5                        21
# ...

# %%
distributors_2018.columns = distributors_2018.columns.str.replace('\n', ' ')
distributors_2018.columns = distributors_2018.columns.str.replace('(%)', '')
distributors_2018.head()
# Out:
#    Year       Distributor Market share  Films on release in 2018  \
# 0  2018       Walt Disney          23.6                       24
# 1  2018         Universal          19.5                       40
# 2  2018  20th Century Fox          14.5                       28
# 3  2018       Warner Bros          13.9                       31
# 4  2018              Sony          10.7                       33
#
#   Box office gross (£ million)
# 0                        325.6
# 1                        268.5
# 2                        199.3
# 3                        191.4
# 4                        146.8

# %%
distributors_2018=distributors_2018.rename(columns={"Films on release in 2018": "Films on release"})
distributors_2018.head()
# Out:
#    Year       Distributor Market share  Films on release  \
# 0  2018       Walt Disney          23.6               24
# 1  2018         Universal          19.5               40
# 2  2018  20th Century Fox          14.5               28
# 3  2018       Warner Bros          13.9               31
# 4  2018              Sony          10.7               33
#
#   Box office gross (£ million)
# 0                        325.6
# 1                        268.5
# 2                        199.3
# 3                        191.4
# 4                        146.8

# %% [markdown]
# ## Setting up 2019
# repeat the process for 2019, 2020, 2021

# %%
tables_2019 = extract_tables("/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2020 - BFI Statistical Yearbook 2020 - 12815.pdf", pages=[11,36,63])
# Out:
# Reading /content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2020 - BFI Statistical Yearbook 2020 - 12815.pdf
# 4 tables found
#
# #######################
# 	Table 0
# ##################
#          Territory Admissions 2018\n(million) Admissions 2019\n(million)  \
# 0            China                      1,717                      1,727
# 1            India                      1,463                      1,592
# 2   USA and Canada                      1,310                      1,256
# 3           Mexico                        332                        350
# 4      South Korea                        216                        227
# 5           Russia                        200                        219
# 6           France                        201                        213
# 7            Japan                        169                        195
# ...

# %% [markdown]
# #### Admissions

# %%
# Admissions table

admissions_2019 = (
    tables_2019[1]
    .iloc[:,[0,2]]
)

admissions_2019.columns = ['Month', 'Admissions (million)']

admissions_2019.insert(0, 'Year', 2019)

admissions_2019.head()
# Out:
#    Year     Month Admissions (million)
# 0  2019   January                 13.7
# 1  2019  February                 12.2
# 2  2019     March                 11.4
# 3  2019     April                 16.0
# 4  2019       May                 16.6

# %%
admissions_2019.tail()
# Out:
#     Year      Month Admissions (million)
# 7   2019     August                 15.6
# 8   2019  September                 11.0
# 9   2019    October                 16.3
# 10  2019   November                 12.2
# 11  2019   December                 18.5

# %% [markdown]
# ### Genres

# %%
genres_2019 = (
    tables_2019[2]
    .drop(columns=[tables_2019[2].columns[2], tables_2019[2].columns[4]])
)

genres_2019.insert(0, "Year", 2019)

genres_2019.columns = ["Year", "Genre", "Number of releases", "Gross box office (£ million)", "Top performing title"]

genres_2019.head(7)
# Out:
#    Year      Genre Number of releases Gross box office (£ million)  \
# 0  2019     Action                102                        328.3
# 1  2019  Animation                 40                        312.1
# 2  2019      Drama                264                        166.4
# 3  2019     Comedy                136                         83.5
# 4  2019     Biopic                 19                         80.7
# 5  2019   Thriller                 20                         75.3
# 6  2019     Sci-fi                  3                         64.3
#
#                Top performing title
# 0                 Avengers: Endgame
# 1                     The Lion King
# 2                     Downton Abbey
# 3                         Yesterday
# 4                         Rocketman
# 5                             Joker
# 6  Star Wars: The Rise of Skywalker

# %% [markdown]
# ### Distributors

# %%
distributors_2019 = (
    tables_2019[3] # select the thrid table
    .drop(index=[10]) # drop totals except the row totalling 'others'
)

distributors_2019.insert(0, "Year", 2019)

distributors_2019.columns = ["Year", "Distributor", "Market share", "Films on release", "Box office gross (£ million)"]

distributors_2019.head()
# Out:
#    Year  Distributor Market share Films on release  \
# 0  2019  Walt Disney         37.9               24
# 1  2019    Universal         13.9               39
# 2  2019  Warner Bros         12.4               40
# 3  2019         Sony          9.3               27
# 4  2019    Paramount          5.9               13
#
#   Box office gross (£ million)
# 0                        506.8
# 1                        185.6
# 2                        166.3
# 3                        124.7
# 4                         79.0

# %% [markdown]
# ## 2020

# %%
tables_2020 = extract_tables("/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2021 - BFI Statistical Yearbook 2021 - 24979.pdf", pages=[10,35,60])
# Out:
# Reading /content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2021 - BFI Statistical Yearbook 2021 - 24979.pdf
# 4 tables found
#
# #######################
# 	Table 0
# ##################
#    Admissions\n(million)  2016  2017  2018  2019  2020 % change\non 2019
# 0                January  14.0  15.0  16.2  13.7  16.5              20.4
# 1               February  15.4  16.5  16.1  12.2  14.5              19.0
# 2                  March  13.4  16.2  13.5  11.4   4.8             -57.9
# 3                  April  13.1  15.6  15.5  16.0     -            -100.0
# 4                    May  12.5  11.3  13.7  16.6     -            -100.0
# 5                   June  10.7   9.6  10.4  13.9     -            -100.0
# 6                   July  16.6  17.8  15.6  18.7   0.4             -97.9
# 7                 August  18.1  14.5  19.2  15.6   2.1             -86.7
# ...

# %% [markdown]
# ### Admissions

# %%
admissions_2020 = (
    tables_2020[0]
    .iloc[:,[0,5]]
)

admissions_2020.columns = ["Month", "Admissions (million)"]
admissions_2020.insert(0, "Year", 2020)

admissions_2020.head()
# Out:
#    Year     Month Admissions (million)
# 0  2020   January                 16.5
# 1  2020  February                 14.5
# 2  2020     March                  4.8
# 3  2020     April                    -
# 4  2020       May                    -

# %%
# Replace '-' with NaN
admissions_2020 = admissions_2020.replace("-", np.NaN)
admissions_2020.head()
# Out:
#    Year     Month Admissions (million)
# 0  2020   January                 16.5
# 1  2020  February                 14.5
# 2  2020     March                  4.8
# 3  2020     April                  NaN
# 4  2020       May                  NaN

# %% [markdown]
# ### Genres

# %%
genres_2020 = (
    tables_2020[1]
    .drop(columns=[tables_2020[1].columns[2], tables_2020[1].columns[4], tables_2020[1].columns[5]])
)

genres_2020.insert(0, "Year", 2020)

genres_2020.columns = ["Year", "Genre", "Number of releases","Gross box office (£ million)", "Top performing title"]

genres_2020.head(8)
# Out:
#    Year      Genre Number of releases Gross box office (£ million)  \
# 0  2020     Action                 36                         48.5
# 1  2020        War                  3                         44.3
# 2  2020  Animation                 19                         34.8
# 3  2020   Thriller                 15                         32.8
# 4  2020      Drama                140                         31.4
# 5  2020     Comedy                 65                         24.0
# 6  2020      Crime                  8                         12.5
# 7  2020     Horror                 24                         12.1
#
#                          Top performing title
# 0                           Bad Boys For Life
# 1                                        1917
# 2                          Sonic The Hedgehog
# 3                                       Tenet
# 4  The Personal History of\nDavid Copperfield
# 5                                 Jojo Rabbit
# ...

# %%
genres_2020.tail()
# Out:
#     Year        Genre Number of releases Gross box office (£ million)  \
# 11  2020  Documentary                 42                          0.4
# 12  2020      Western                  2                          0.3
# 13  2020       Family                  3                          0.3
# 14  2020       Biopic                  3                          0.2
# 15  2020       Sci fi                  4                          0.1
#
#                      Top performing title
# 11                             I Am Greta
# 12         True History Of The Kelly Gang
# 13  Max Winslow And The\nHouse Of Secrets
# 14                              Mr. Jones
# 15                     Color Out Of Space

# %%
# Fix the "\n" error

genres_2020["Top performing title"] = genres_2020["Top performing title"].str.replace("\n", " ")

genres_2020.head()
# Out:
#    Year      Genre Number of releases Gross box office (£ million)  \
# 0  2020     Action                 36                         48.5
# 1  2020        War                  3                         44.3
# 2  2020  Animation                 19                         34.8
# 3  2020   Thriller                 15                         32.8
# 4  2020      Drama                140                         31.4
#
#                         Top performing title
# 0                          Bad Boys For Life
# 1                                       1917
# 2                         Sonic The Hedgehog
# 3                                      Tenet
# 4  The Personal History of David Copperfield

# %%
genres_2020.tail()
# Out:
#     Year        Genre Number of releases Gross box office (£ million)  \
# 11  2020  Documentary                 42                          0.4
# 12  2020      Western                  2                          0.3
# 13  2020       Family                  3                          0.3
# 14  2020       Biopic                  3                          0.2
# 15  2020       Sci fi                  4                          0.1
#
#                     Top performing title
# 11                            I Am Greta
# 12        True History Of The Kelly Gang
# 13  Max Winslow And The House Of Secrets
# 14                             Mr. Jones
# 15                    Color Out Of Space

# %% [markdown]
# ### Distributors

# %%
distributors_2020 = (
    tables_2020[2]
    .iloc[:,:4]
    .drop(index=[10]) # drop totals except the row totalling "others"
)

distributors_2020.insert(0, "Year", 2020)

distributors_2020.columns = ["Year", "Distributor", "Market share", "Films on release", "Box office gross (£ million)"]

distributors_2020.head()
# Out:
#    Year        Distributor Market share Films on release  \
# 0  2020  Entertainment One         15.9               30
# 1  2020               Sony         15.6               38
# 2  2020        Walt Disney         14.3               58
# 3  2020          Universal         12.5               73
# 4  2020        Warner Bros         11.7               89
#
#   Box office gross (£ million)
# 0                         49.4
# 1                         48.4
# 2                         44.3
# 3                         39.0
# 4                         36.5

# %% [markdown]
# ## 2021

# %%
tables_2021 = extract_tables("/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2022 - The box office 2021 - full report - 26781.pdf", pages=[6])
# Out:
# Reading /content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2022 - The box office 2021 - full report - 26781.pdf
# 1 tables found
#
# #######################
# 	Table 0
# ##################
#    Admissions (million)  2019  2020  2021 % change on 2019
# 0               January  13.7  16.5     -           -100.0
# 1              February  12.2  14.5     -           -100.0
# 2                 March  11.4   4.8     -           -100.0
# 3                 April  16.0     -     -           -100.0
# 4                   May  16.6     -   3.5            -78.8
# 5                  June  13.9     -   7.0            -49.9
# 6                  July  18.7   0.4   7.8            -58.5
# 7                August  15.6   2.1  10.4            -33.1
# 8             September  11.0   2.7   6.5            -40.6
# 9               October  16.3   2.2  16.4              0.9
# 10             November  12.2   0.3   8.8            -27.5
# ...

# %% [markdown]
# ### Admissions

# %%
admissions_2021 = (
    tables_2021[0].iloc[:,[0,3]]
)

# %%
admissions_2021.head()
# Out:
#   Admissions (million) 2021
# 0              January    -
# 1             February    -
# 2                March    -
# 3                April    -
# 4                  May  3.5

# %%
admissions_2021.columns = ["Month", "Admissions (million)"]
admissions_2021.insert(0, "Year", 2021)

admissions_2021["Admissions (million)"] = admissions_2021["Admissions (million)"].replace("-", np.NaN) #replace "-" with NaN

admissions_2021.head()
# Out:
# <ipython-input-353-885be1e59de5>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   admissions_2021["Admissions (million)"] = admissions_2021["Admissions (million)"].replace("-", np.NaN) #replace "-" with NaN
#    Year     Month Admissions (million)
# 0  2021   January                  NaN
# 1  2021  February                  NaN
# 2  2021     March                  NaN
# 3  2021     April                  NaN
# 4  2021       May                  3.5

# %%
admissions_2021.tail()
# Out:
#     Year      Month Admissions (million)
# 7   2021     August                 10.4
# 8   2021  September                  6.5
# 9   2021    October                 16.4
# 10  2021   November                  8.8
# 11  2021   December                 13.5

# %% [markdown]
# ### Genres

# %%
tables_genres_2021 = extract_tables("/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2022 - Top films in 2021 - full report - 29763.pdf", pages=[13])
# Out:
# Reading /content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2022 - Top films in 2021 - full report - 29763.pdf
# 1 tables found
#
# #######################
# 	Table 0
# ##################
#           Genre Number\nof releas-\nes % of\nreleases  \
# 0        Action                     52           11.8
# 1        Comedy                     54           12.2
# 2     Animation                     38            8.6
# 3        Horror                     24            5.4
# 4        Family                      8            1.8
# 5        Sci fi                      4            0.9
# 6         Drama                    134           30.3
# 7       Musical                      8            1.8
# 8     Adventure                      6            1.4
# 9       Fantasy                      3            0.7
# 10       Biopic                      5            1.1
# 11     Thriller                     10            2.3
# ...

# %%
genres_2021 = (
    tables_genres_2021[0]
    .drop(columns=[tables_genres_2021[0].columns[2], tables_genres_2021[0].columns[4], tables_genres_2021[0].columns[5]])
)

genres_2021.insert(0, "Year", 2021)

genres_2021.columns = ["Year", "Genre", "Number of releases", "Gross box office (£ million)", "Top performing title"]

# fix errors
genres_2021["Top performing title"] = genres_2021['Top performing title'].str.replace("\n", " ")

genres_2021.head()
# Out:
#    Year      Genre Number of releases Gross box office (£ million)  \
# 0  2021     Action                 52                        296.7
# 1  2021     Comedy                 54                         65.1
# 2  2021  Animation                 38                         58.2
# 3  2021     Horror                 24                         40.8
# 4  2021     Family                  8                         29.6
#
#           Top performing title
# 0               No Time to Die
# 1                     Free Guy
# 2          The Addams Family 2
# 3        A Quiet Place Part II
# 4  Peter Rabbit 2: The Runaway

# %% [markdown]
# ### Distributors

# %%
tables_2021_dist = extract_tables('/content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2022 - Distribution - full report - 26782.pdf', pages=[4])
# Out:
# Reading /content/drive/MyDrive/year 29/Data Science /notebooks/solve_any_data_analysis_problem/project_4/pdf_files_notebook/2022 - Distribution - full report - 26782.pdf
# 1 tables found
#
# #######################
# 	Table 0
# ##################
#                  Distributor Market share in 2021 (%)  \
# 0                  Universal                     30.6
# 1                       Sony                     22.2
# 2                Walt Disney                     21.2
# 3                Warner Bros                     14.4
# 4                  Paramount                      3.7
# 5                  Lionsgate                      1.8
# 6          Entertainment One                      1.4
# 7                Park Circus                      0.6
# 8          STX Entertainment                      0.6
# 9                StudioCanal                      0.5
# 10                    Top 10                     96.8
# 11  Other distributors (137)                      3.2
#
# ...

# %%
distributors_2021 = (
    tables_2021_dist[0]
    .drop(index=[10]) # drop Top total row
)

distributors_2021.insert(0, "Year", 2021)
distributors_2021.columns = ["Year", "Distributor", "Market share", "Films on release", "Box office gross (£ million)"]
distributors_2021.head()
# Out:
#    Year  Distributor Market share Films on release  \
# 0  2021    Universal         30.6               51
# 1  2021         Sony         22.2               52
# 2  2021  Walt Disney         21.2               63
# 3  2021  Warner Bros         14.4               80
# 4  2021    Paramount          3.7               16
#
#   Box office gross (£ million)
# 0                        180.8
# 1                        130.8
# 2                        125.1
# 3                         84.7
# 4                         21.8

# %%
distributors_2021.tail()
# Out:
#     Year               Distributor Market share Films on release  \
# 6   2021         Entertainment One          1.4               12
# 7   2021               Park Circus          0.6               96
# 8   2021         STX Entertainment          0.6                3
# 9   2021               StudioCanal          0.5               36
# 11  2021  Other distributors (137)          3.2              549
#
#    Box office gross (£ million)
# 6                           8.1
# 7                           3.4
# 8                           3.4
# 9                           2.7
# 11                         19.0

# %% [markdown]
# # Combine it all

# %% [markdown]
# #### admissions

# %%
admissions = pd.concat([admissions_2018, admissions_2019,admissions_2020, admissions_2021],
                       ignore_index=True,
                       axis=0)
admissions.head()
# Out:
#    Year     Month Admissions (million)
# 0  2018   January                 16.2
# 1  2018  February                 16.1
# 2  2018     March                 13.5
# 3  2018     April                 15.5
# 4  2018       May                 13.7

# %%
admissions["Year"].value_counts()
# Out:
# Year
# 2018    12
# 2019    12
# 2020    12
# 2021    12
# Name: count, dtype: int64

# %%
admissions.to_csv("admissions.csv", index=False)

# %% [markdown]
# #### Genres

# %%
genres = pd.concat([genres_2018, genres_2019,genres_2020, genres_2021],
                       ignore_index=True,
                       axis=0)
genres.head()
# Out:
#    Year      Genre Number of releases Gross box office (£ million)  \
# 0  2018     Action                 77                        361.3
# 1  2018  Animation                 46                        242.2
# 2  2018      Drama                246                        154.1
# 3  2018     Comedy                144                         88.3
# 4  2018     Biopic                  5                         78.5
#
#            Top performing title
# 0        Avengers: Infinity War
# 1                 Incredibles 2
# 2                A Star Is Born
# 3  Johnny English Strikes Again
# 4             Bohemian Rhapsody

# %%
genres["Year"].value_counts()
# Out:
# Year
# 2018    18
# 2019    17
# 2020    16
# 2021    16
# Name: count, dtype: int64

# %%
genres.to_csv('genres.csv', index=False)

# %% [markdown]
# #### Distributors

# %%
distributors = pd.concat([distributors_2018, distributors_2019, distributors_2020, distributors_2021],
                       ignore_index=True,
                       axis=0)

# %%
distributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          44 non-null     int64
#  1   Distributor                   44 non-null     object
#  2   Market share                  11 non-null     object
#  3   Films on release              44 non-null     object
#  4   Box office gross (£ million)  44 non-null     object
#  5   Market share                  33 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 2.2+ KB

# %%
distributors.head()
# Out:
#    Year       Distributor Market share  Films on release  \
# 0  2018       Walt Disney          23.6               24
# 1  2018         Universal          19.5               40
# 2  2018  20th Century Fox          14.5               28
# 3  2018       Warner Bros          13.9               31
# 4  2018              Sony          10.7               33
#
#   Box office gross (£ million) Market share
# 0                        325.6          NaN
# 1                        268.5          NaN
# 2                        199.3          NaN
# 3                        191.4          NaN
# 4                        146.8          NaN

# %%
distributors.sample(12)
# Out:
#     Year        Distributor Market share  Films on release  \
# 37  2021          Paramount           NaN               16
# 41  2021  STX Entertainment           NaN                3
# 22  2020  Entertainment One           NaN               30
# 39  2021  Entertainment One           NaN               12
# 28  2020          Lionsgate           NaN               29
# 25  2020          Universal           NaN               73
# 35  2021        Walt Disney           NaN               63
# 8   2018          Lionsgate           1.5               21
# 15  2019          Paramount           NaN               13
# 23  2020               Sony           NaN               38
# 20  2019        StudioCanal           NaN               22
# 40  2021        Park Circus           NaN               96
#
#    Box office gross (£ million) Market share
# 37                         21.8          3.7
# 41                          3.4          0.6
# 22                         49.4         15.9
# ...

# %%
distributors['Market share'] = distributors['Market share'].fillna(distributors['Market share '])
distributors.head()
# Out:
#    Year       Distributor Market share  Films on release  \
# 0  2018       Walt Disney          23.6               24
# 1  2018         Universal          19.5               40
# 2  2018  20th Century Fox          14.5               28
# 3  2018       Warner Bros          13.9               31
# 4  2018              Sony          10.7               33
#
#   Box office gross (£ million) Market share
# 0                        325.6         23.6
# 1                        268.5         19.5
# 2                        199.3         14.5
# 3                        191.4         13.9
# 4                        146.8         10.7

# %%
distributors = distributors.drop('Market share ', axis=1)

# %%
distributors.sample(12)
# Out:
#     Year                      Distributor Films on release  \
# 33  2021                        Universal               51
# 41  2021                STX Entertainment                3
# 34  2021                             Sony               52
# 18  2019                Entertainment One               27
# 5   2018                        Paramount               12
# 26  2020                      Warner Bros               89
# 43  2021         Other distributors (137)              549
# 4   2018                             Sony               33
# 6   2018                       eOne Films               22
# 12  2019                        Universal               39
# 28  2020                        Lionsgate               29
# 21  2019  Others (Total 130 distributors)              671
#
#    Box office gross (£ million) Market share
# 33                        180.8         30.6
# 41                          3.4          0.6
# 34                        130.8         22.2
# ...

# %%
distributors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          44 non-null     int64
#  1   Distributor                   44 non-null     object
#  2   Films on release              44 non-null     object
#  3   Box office gross (£ million)  44 non-null     object
#  4   Market share                  44 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ KB

# %%
distributors["Year"].value_counts()
# Out:
# Year
# 2018    11
# 2019    11
# 2020    11
# 2021    11
# Name: count, dtype: int64

# %%
distributors.to_csv("distributors.csv", index=False)
